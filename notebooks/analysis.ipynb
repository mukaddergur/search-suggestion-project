# %% [markdown]
# # Search Suggestion Project Analysis
#
# Bu notebook, sorgu verisini temizleme, ozellik cikarimi ve temel analiz adimlarini gostermek icin olusturuldu.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('../data/search_data.csv')
df = pd.read_csv(data_path)
df.head()

# %%
from src.preprocess import preprocess_queries

grouped_df = preprocess_queries(df)
grouped_df.head()
